# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('fetal_health.csv')
df.head()
# Out:
#    baseline_value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# baseline_value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# histogram_mode                                            0
# histogram_mean                                            0
# histogram_median                                          0
# histogram_variance                                        0
# histogram_tendency                                        0
# fetal_health                                              0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# ##cnn

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_f = st.fit_transform(x) 
from keras.utils import to_categorical
y = np.squeeze(y)
y -= np.min(y)
y = to_categorical(y, num_classes=0)

# %%
import pickle
pickle.dump(st, open('Standard_scalar.pkl', 'wb'))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from keras.models import Sequential
from keras.layers import Conv1D,Dense, Dropout
from tensorflow import keras
import keras.backend as K

from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
model = Sequential()

# Add input layer
model.add(Dense(64, activation='relu', input_shape=(21,)))
model.add(BatchNormalization())

# Add hidden layers
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                │ (None, 64)             │         1,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,315 (83.26 KB)
#  Trainable params: 20,739 (81.01 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
history = model.fit(x_train, y_train,validation_data=(x_test, y_test),batch_size=30,epochs= 27)
# Out:
# Epoch 1/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4806 - loss: 1.1877 - val_accuracy: 0.1878 - val_loss: 3.2565
# Epoch 2/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7948 - loss: 0.6764 - val_accuracy: 0.6150 - val_loss: 1.0928
# Epoch 3/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8265 - loss: 0.5595 - val_accuracy: 0.8216 - val_loss: 0.5760
# Epoch 4/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8336 - loss: 0.5459 - val_accuracy: 0.8615 - val_loss: 0.4420
# Epoch 5/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8328 - loss: 0.4837 - val_accuracy: 0.8615 - val_loss: 0.3965
# Epoch 6/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8701 - loss: 0.3932 - val_accuracy: 0.8850 - val_loss: 0.3478
# Epoch 7/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8562 - loss: 0.3995 - val_accuracy: 0.8732 - val_loss: 0.3558
# Epoch 8/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8610 - loss: 0.3851 - val_accuracy: 0.8944 - val_loss: 0.3082
# Epoch 9/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.3957 - val_accuracy: 0.8850 - val_loss: 0.3160
# Epoch 10/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8696 - loss: 0.3723 - val_accuracy: 0.8779 - val_loss: 0.3537
# Epoch 11/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8877 - loss: 0.3309 - val_accuracy: 0.8920 - val_loss: 0.2915
# Epoch 12/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8638 - loss: 0.3530 - val_accuracy: 0.8897 - val_loss: 0.3030
# Epoch 13/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8674 - loss: 0.3635 - val_accuracy: 0.8850 - val_loss: 0.3111
# Epoch 14/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8581 - loss: 0.3343 - val_accuracy: 0.8709 - val_loss: 0.3314
# Epoch 15/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8732 - loss: 0.3249 - val_accuracy: 0.8685 - val_loss: 0.3239
# Epoch 16/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8606 - loss: 0.3534 - val_accuracy: 0.8709 - val_loss: 0.3358
# Epoch 17/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8850 - loss: 0.3198 - val_accuracy: 0.8685 - val_loss: 0.3493
# Epoch 18/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8633 - loss: 0.3372 - val_accuracy: 0.8779 - val_loss: 0.3129
# Epoch 19/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8743 - loss: 0.3319 - val_accuracy: 0.8850 - val_loss: 0.2982
# Epoch 20/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8596 - loss: 0.3422 - val_accuracy: 0.8779 - val_loss: 0.2932
# Epoch 21/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8742 - loss: 0.3246 - val_accuracy: 0.8779 - val_loss: 0.3270
# Epoch 22/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8796 - loss: 0.2776 - val_accuracy: 0.8545 - val_loss: 0.3319
# Epoch 23/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8775 - loss: 0.2906 - val_accuracy: 0.8920 - val_loss: 0.2872
# Epoch 24/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8798 - loss: 0.2965 - val_accuracy: 0.8967 - val_loss: 0.2715
# Epoch 25/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.3073 - val_accuracy: 0.8967 - val_loss: 0.2869
# Epoch 26/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.2939 - val_accuracy: 0.8803 - val_loss: 0.3097
# Epoch 27/27
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9022 - loss: 0.2424 - val_accuracy: 0.8873 - val_loss: 0.2868

# %%
import matplotlib.pyplot as plt


# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
loss,accuracy= model.evaluate(x_test,y_test)
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1218
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9021 - loss: 0.2607
# Loss:  0.2867843806743622
# Accuracy:  0.8873239159584045

# %%
from keras.models import load_model 
model.save("fetalcnn1.h5") 
loaded_model = load_model("fetalcnn1.h5") 
loss, accuracy = loaded_model.evaluate(x_test,y_test) 
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - accuracy: 0.9021 - loss: 0.2607
# Loss:  0.2867843806743622
# Accuracy:  0.8873239159584045

# %% [markdown]
# ##dnn

# %%
from sklearn.preprocessing import LabelEncoder
y=df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x_f, y, test_size=0.2, random_state=42)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test= label_encoder.fit_transform(y_test)

# %%
from keras.models import Sequential
import keras
fatal_model = Sequential([
  keras.layers.Dense(512, activation="relu"),
  keras.layers.Dense(512, activation="relu"),
  keras.layers.Dense(256, activation="relu"),
  keras.layers.Dense(128, activation="relu"),
  keras.layers.Dense(56, activation="relu"),
  keras.layers.Dense(3, activation="softmax")
])
fatal_model.compile(loss='sparse_categorical_crossentropy', 
                 optimizer='adam',
                 metrics=['accuracy'])
fatal_model_history =fatal_model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100)
# Out:
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7435 - loss: 0.6665 - val_accuracy: 0.8568 - val_loss: 0.3435
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8922 - loss: 0.2525 - val_accuracy: 0.8991 - val_loss: 0.2612
# Epoch 3/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9022 - loss: 0.2541 - val_accuracy: 0.8732 - val_loss: 0.2720
# Epoch 4/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9046 - loss: 0.2090 - val_accuracy: 0.8850 - val_loss: 0.2610
# Epoch 5/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9258 - loss: 0.1625 - val_accuracy: 0.8967 - val_loss: 0.2560
# Epoch 6/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9299 - loss: 0.1712 - val_accuracy: 0.8897 - val_loss: 0.2961
# Epoch 7/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9349 - loss: 0.1451 - val_accuracy: 0.9061 - val_loss: 0.2457
# Epoch 8/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9324 - loss: 0.1752 - val_accuracy: 0.9061 - val_loss: 0.2346
# Epoch 9/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9463 - loss: 0.1197 - val_accuracy: 0.9131 - val_loss: 0.2230
# Epoch 10/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9525 - loss: 0.1136 - val_accuracy: 0.9085 - val_loss: 0.2328
# Epoch 11/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9630 - loss: 0.1093 - val_accuracy: 0.9202 - val_loss: 0.2229
# Epoch 12/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.0975 - val_accuracy: 0.9131 - val_loss: 0.2448
# Epoch 13/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9595 - loss: 0.0876 - val_accuracy: 0.9014 - val_loss: 0.2404
# Epoch 14/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9634 - loss: 0.0835 - val_accuracy: 0.9272 - val_loss: 0.2649
# Epoch 15/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9711 - loss: 0.0738 - val_accuracy: 0.9014 - val_loss: 0.3097
# Epoch 16/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9664 - loss: 0.0876 - val_accuracy: 0.9131 - val_loss: 0.2459
# Epoch 17/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9697 - loss: 0.0640 - val_accuracy: 0.9155 - val_loss: 0.2912
# Epoch 18/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9537 - loss: 0.1144 - val_accuracy: 0.9178 - val_loss: 0.3358
# Epoch 19/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9652 - loss: 0.0802 - val_accuracy: 0.9249 - val_loss: 0.3046
# Epoch 20/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0568 - val_accuracy: 0.9038 - val_loss: 0.3080
# Epoch 21/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9976 - loss: 0.0099 - val_accuracy: 0.9249 - val_loss: 0.6496
# Epoch 91/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0199 - val_accuracy: 0.9178 - val_loss: 0.4711
# Epoch 92/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9910 - loss: 0.0185 - val_accuracy: 0.9085 - val_loss: 0.6026
# Epoch 93/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9973 - loss: 0.0099 - val_accuracy: 0.9296 - val_loss: 0.5632
# Epoch 94/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9936 - loss: 0.0179 - val_accuracy: 0.9249 - val_loss: 0.5409
# Epoch 95/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9949 - loss: 0.0152 - val_accuracy: 0.9296 - val_loss: 0.5899
# Epoch 96/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9909 - loss: 0.0244 - val_accuracy: 0.9343 - val_loss: 0.6987
# Epoch 97/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9960 - loss: 0.0091 - val_accuracy: 0.9319 - val_loss: 0.7404
# Epoch 98/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9926 - loss: 0.0143 - val_accuracy: 0.9108 - val_loss: 0.9198
# Epoch 99/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9743 - loss: 0.1173 - val_accuracy: 0.9178 - val_loss: 0.3333
# Epoch 100/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9704 - loss: 0.0874 - val_accuracy: 0.8920 - val_loss: 0.5706

# %%
import matplotlib.pyplot as plt


# Plot training & validation accuracy values
plt.plot(fatal_model_history.history['accuracy'])
plt.plot(fatal_model_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(fatal_model_history.history['loss'])
plt.plot(fatal_model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
pd.DataFrame(fatal_model_history.history).plot()
# Out:
# <Axes: >

# %%
loss,accuracy = fatal_model.evaluate(x_test,y_test)
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8958 - loss: 0.5889
# Loss:  0.5706236958503723
# Accuracy:  0.8920187950134277

# %%
from keras.models import load_model 
fatal_model.save("fetaldnn1.h5") 
loaded_model = load_model("fetaldnn1.h5") 
loss, accuracy = loaded_model.evaluate(x_test,y_test) 
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8958 - loss: 0.5889
# Loss:  0.5706236958503723
# Accuracy:  0.8920187950134277

# %% [markdown]
# ##ann

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
yr= pd.get_dummies(y)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xs= scaler.fit_transform(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(xs,yr,test_size=0.2)

# %%
model_a = keras.Sequential([keras.layers.Dense(20,input_dim =(x_train.shape[1]),activation="relu",kernel_initializer="HeNormal"),
                          keras.layers.Dense(40,activation="relu"),
                          keras.layers.Dense(80,activation="relu"),
                          keras.layers.Dropout(0.3),
                          keras.layers.Dense(160,activation="relu"),
                          keras.layers.Dense(320,activation="relu"),
                          keras.layers.Dropout(0.3),
                          keras.layers.Dense(640,activation="relu"),
                          keras.layers.Dense(3,activation="softmax")
                         ])

# %%
model_a.compile(loss=keras.losses.CategoricalCrossentropy(), 
                 optimizer='rmsprop',
                 metrics=['accuracy'])
history_a = model_a.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=101)
# Out:
# Epoch 1/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7335 - loss: 0.6299 - val_accuracy: 0.8451 - val_loss: 0.3933
# Epoch 2/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8370 - loss: 0.4180 - val_accuracy: 0.8075 - val_loss: 0.6119
# Epoch 3/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8449 - loss: 0.3947 - val_accuracy: 0.8592 - val_loss: 0.3051
# Epoch 4/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8633 - loss: 0.3156 - val_accuracy: 0.8850 - val_loss: 0.2686
# Epoch 5/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8801 - loss: 0.3089 - val_accuracy: 0.8732 - val_loss: 0.3248
# Epoch 6/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8910 - loss: 0.2560 - val_accuracy: 0.8967 - val_loss: 0.2545
# Epoch 7/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9043 - loss: 0.2458 - val_accuracy: 0.8944 - val_loss: 0.2742
# Epoch 8/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9774 - loss: 0.0662 - val_accuracy: 0.9272 - val_loss: 0.4008
# Epoch 75/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.0687 - val_accuracy: 0.9225 - val_loss: 0.5072
# Epoch 76/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9758 - loss: 0.0516 - val_accuracy: 0.9249 - val_loss: 0.4530
# Epoch 77/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9761 - loss: 0.0615 - val_accuracy: 0.9178 - val_loss: 0.5448
# Epoch 78/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9745 - loss: 0.0738 - val_accuracy: 0.9178 - val_loss: 0.4333
# Epoch 79/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9729 - loss: 0.0676 - val_accuracy: 0.9178 - val_loss: 0.4693
# Epoch 80/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9774 - loss: 0.0616 - val_accuracy: 0.9108 - val_loss: 0.4485
# Epoch 81/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9746 - loss: 0.0558 - val_accuracy: 0.9155 - val_loss: 0.4413
# Epoch 82/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.0638 - val_accuracy: 0.9202 - val_loss: 0.4487
# Epoch 83/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9803 - loss: 0.0496 - val_accuracy: 0.9296 - val_loss: 0.4716
# Epoch 84/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9793 - loss: 0.0526 - val_accuracy: 0.9202 - val_loss: 0.5206
# Epoch 85/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9815 - loss: 0.0554 - val_accuracy: 0.9202 - val_loss: 0.4753
# Epoch 86/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9836 - loss: 0.0423 - val_accuracy: 0.9085 - val_loss: 0.6667
# Epoch 87/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9814 - loss: 0.0496 - val_accuracy: 0.9038 - val_loss: 0.5491
# Epoch 88/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9739 - loss: 0.0694 - val_accuracy: 0.9014 - val_loss: 0.5887
# Epoch 89/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9738 - loss: 0.0572 - val_accuracy: 0.9061 - val_loss: 0.5978
# Epoch 90/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9723 - loss: 0.0689 - val_accuracy: 0.9202 - val_loss: 0.5691
# Epoch 91/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0513 - val_accuracy: 0.9131 - val_loss: 0.5334
# Epoch 92/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9820 - loss: 0.0548 - val_accuracy: 0.9202 - val_loss: 0.6800
# Epoch 93/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9744 - loss: 0.0730 - val_accuracy: 0.9155 - val_loss: 0.6149
# Epoch 94/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9799 - loss: 0.0565 - val_accuracy: 0.9131 - val_loss: 0.5994
# Epoch 95/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9779 - loss: 0.0535 - val_accuracy: 0.9085 - val_loss: 0.5520
# Epoch 96/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9842 - loss: 0.0447 - val_accuracy: 0.9108 - val_loss: 0.7606
# Epoch 97/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9720 - loss: 0.0699 - val_accuracy: 0.9178 - val_loss: 0.6178
# Epoch 98/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9802 - loss: 0.0547 - val_accuracy: 0.9178 - val_loss: 0.5427
# Epoch 99/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9698 - loss: 0.0745 - val_accuracy: 0.9155 - val_loss: 0.6079
# Epoch 100/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0438 - val_accuracy: 0.9014 - val_loss: 0.6167
# Epoch 101/101
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9800 - loss: 0.0476 - val_accuracy: 0.9296 - val_loss: 0.5561

# %%
import matplotlib.pyplot as plt


# Plot training & validation accuracy values
plt.plot(history_a.history['accuracy'])
plt.plot(history_a.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history_a.history['loss'])
plt.plot(history_a.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
loss,accuracy= model_a.evaluate(x_test,y_test)
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.9228 - loss: 0.6855
# Loss:  0.5560581088066101
# Accuracy:  0.9295774698257446

# %%
from keras.models import load_model 
model_a.save("fetalann1.h5") 
loaded_model = load_model("fetalann1.h5") 
loss, accuracy = loaded_model.evaluate(x_test,y_test) 
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9228 - loss: 0.6855
# Loss:  0.5560581088066101
# Accuracy:  0.9295774698257446
